# %%
import numpy as np
import matplotlib.pyplot as plt
vetor = np.random.normal(100.0, 20.00, 10000)
plt.hist(vetor, 50)
plt.show()

# %%
vetor.std()
# Out:
# 19.79039381645

# %%
vetor.var()
# Out:
# 391.6596874101823
